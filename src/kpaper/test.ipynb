# %%
from paper import KPaperConfig
from kbasic import Folder
import tomllib

# %%
c = KPaperConfig(Folder("../../../"))
print("\n".join(c.lines))
c.save()
# Out:
# # KPaper v.0.1.21 Configuration File
# title = packages
# abstract = [authors]names = [, Keyan Gootkin]

# %%
c
# Out:
# /Users/keyan/code/packages/kpaper.toml
