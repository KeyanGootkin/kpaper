# %%
from IPython.display import Markdown

# %%
from importlib.metadata import version 
print(version('kbasic'))

from paper import KPaperConfig
from kbasic import Folder
c = KPaperConfig(Folder("/Users/keyan/code/packages/kpaper.toml"))
# Out:
# 0.1.16

# %%
Markdown(f"# Authors\n[{c.authors[0]}](https://www.keyangootkin.com)")
# Out:
# # Authors
# [Keyan Gootkin](https://www.keyangootkin.com)

# %% [markdown]
# ### authors = {{c.authors}}
# {{c}}
